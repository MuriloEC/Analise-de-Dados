# %%
import pandas as pd

import numpy as np

from collections import OrderedDict

data = OrderedDict({

  'País': ['Bélgica', 'Índia', 'Brasil','Índia'],

  'Capital': ['Bruxelas', 'Nova Delhi', 'Brasília', 'Nova Delhi'],

  'População': [123465, 456789, 987654, 456789]

})

df = pd.DataFrame(data)

df

df_clean = df.drop_duplicates()

df_clean


paises = df.País

df_duplicates = df[paises.isin(paises[paises.duplicated()])]

df_duplicates
# Out:
#     País     Capital  População
# 1  Índia  Nova Delhi     456789
# 3  Índia  Nova Delhi     456789

# %%
a=np.array([[1,2,3],[3,2,6],[2,6,3]])

dfa= pd.DataFrame(a,columns=['A','B','C'])



id = pd.Series([10, 30, 50])



# colocando um index novo id

dfa.set_index(id, inplace = True)
print(dfa)



# colocando uma coluna como index

dfa.set_index('A', inplace = True)

dfa
# Out:
#     A  B  C
# 10  1  2  3
# 30  3  2  6
# 50  2  6  3
#    B  C
# A
# 1  2  3
# 3  2  6
# 2  6  3

# %%
d = {'col1': [1,2,3,4], 'col2': [4,5,2,4]}

dfd = pd.DataFrame(data=d)

dfd

#criando um dataframe com index data

dias = pd.date_range('20221006',periods=4)

# criando um data frame de um dicionario

d = {'col1': [1,2,3,4], 'col2': [4,5,2,4]}

dfd = pd.DataFrame(data=d,index=dias)

dfd
# Out:
#             col1  col2
# 2022-10-06     1     4
# 2022-10-07     2     5
# 2022-10-08     3     2
# 2022-10-09     4     4

# %%
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/TopicosEspEng1/advertisingTr.csv', sep=';')
print(df)
# Out:
#         TV Radio  Jornal  Vendas
# 0    230.1  37.8    69.2    22.1
# 1     44.5  39.3    45.1    10.4
# 2     17.2  45,6    69.3    12.0
# 3    151.5  41.3    58.5    16.5
# 4    180.8  10.8    58.4    17.9
# ..     ...   ...     ...     ...
# 199  232.1   8.6     8.7    18.4
# 200   94.2   4.9     8.1    14.0
# 201  177.0   9.3     6.4    14.8
# 202  283.6    42    66.2    25.5
# 203  232.1   8.6     8.7    18.4
#
# [204 rows x 4 columns]

# %%
df2 = df.drop_duplicates()
df2
# Out:
#         TV Radio  Jornal  Vendas
# 0    230.1  37.8    69.2    22.1
# 1     44.5  39.3    45.1    10.4
# 2     17.2  45,6    69.3    12.0
# 3    151.5  41.3    58.5    16.5
# 4    180.8  10.8    58.4    17.9
# ..     ...   ...     ...     ...
# 195   38.2   3.7    13.8     7.6
# 196   94.2   4.9     8.1    14.0
# 197  177.0   9.3     6.4    14.8
# 198  283.6    42    66.2    25.5
# 199  232.1   8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %%
df3 = df2.apply(pd.to_numeric, errors='coerce')
df3
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2    NaN    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %%
gpRem = df3.loc[(df3["TV"]<0) | (df3["Radio"]<0) | (df3["Jornal"]<0)]
print(gpRem)
print(gpRem.index)
df4 = df3.drop(gpRem.index)
df4
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Jornal, Vendas]
# Index: []
# Index([], dtype='int64')
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2    NaN    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %%
df4 = df4.dropna()
df4
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# 5      8.7   48.9    75.0     7.2
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [192 rows x 4 columns]

# %%
df4.describe()
# Out:
#                TV       Radio      Jornal      Vendas
# count  192.000000  192.000000  192.000000  192.000000
# mean   145.355208   23.017708   29.768750   15.028125
# std     84.637247   14.793861   21.313835    5.248000
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.550000   10.975000
# 50%    145.100000   22.000000   25.600000   15.750000
# 75%    216.500000   35.925000   43.125000   18.900000
# max    296.400000   49.600000  114.000000   27.000000

# %%
selc = df4.loc[(df4["Vendas"]>23.4)]
selc
# Out:
#         TV  Radio  Jornal  Vendas
# 17   281.4   39.6    55.8    24.4
# 36   266.9   43.8     5.0    25.4
# 55   198.9   49.4    60.0    23.7
# 58   210.8   49.6    37.7    23.8
# 61   261.3   42.7    54.7    24.2
# 101  296.4   36.3   100.9    23.8
# 128  220.3   49.0     3.2    24.7
# 147  243.2   49.0    44.3    25.4
# 175  276.9   48.9    41.8    27.0
# 183  287.6   43.0    71.8    26.2
# 198  283.6   42.0    66.2    25.5

# %%
df4.to_csv('/content/drive/MyDrive/TopicosEspEng1/advertisingTr2.csv', sep=';')

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
sns.boxenplot(df4)
# Out:
# <Axes: >

# %%
df4.corr()
# Out:
#               TV     Radio    Jornal    Vendas
# TV      1.000000  0.069001  0.056850  0.899090
# Radio   0.069001  1.000000  0.338519  0.363493
# Jornal  0.056850  0.338519  1.000000  0.151735
# Vendas  0.899090  0.363493  0.151735  1.000000

# %%
sns.heatmap(df4.corr(),cmap='Wistia', annot=True)
# Out:
# <Axes: >

# %%
x = df4.drop('Vendas', axis=1)
y = df4['Vendas']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(x_test)
r2 = metrics.r2_score(y_test, y_pred)
print(f"R2 de regressão: {r2}")
#print(f"MSE da regressão: {mse}")
# Out:
# R2 de regressão: 0.8933367569936672
